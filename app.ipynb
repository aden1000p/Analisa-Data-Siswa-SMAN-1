# %%
import pandas as pd
import numpy as np

df = pd.read_excel("./data_siswa.xlsx")
df
# Out:
#     No               Nama  Bahasa Indonesia  Bahasa Inggris  Matematika  \
# 0    1               Aang                90              80          90
# 1    2               Ajis                80              70          90
# 2    3               Asri                70              70          90
# 3    4               Bayu                80              80          80
# 4    5              Bagas                90              90          70
# 5    6              Chery                80              90          75
# 6    7               Caca                75              80          80
# 7    8              Dimas                86              75          80
# 8    9              Elisa                70              75          85
# 9   10              Fadly                80              75          90
# 10  11              Ikbal                70              80          70
# 11  12  Muhammad Al madid                90              85          70
# ...

# %%
df.describe()
# Out:
#               No  Bahasa Indonesia  Bahasa Inggris  Matematika     Fisika  \
# count  30.000000         30.000000       30.000000   30.000000  30.000000
# mean   15.500000         79.233333       79.333333   79.833333  79.333333
# std     8.803408          6.641995        6.260623    7.249653   6.121378
# min     1.000000         70.000000       70.000000   70.000000  70.000000
# 25%     8.250000         75.000000       75.000000   75.000000  75.000000
# 50%    15.500000         80.000000       80.000000   80.000000  80.000000
# 75%    22.750000         83.750000       80.000000   85.000000  80.000000
# max    30.000000         90.000000       90.000000   90.000000  90.000000
#
#            Kimia    Biologi  PJOK  Matematika_Peminatan  Agama       Pkn   \
# count  30.000000  30.000000  30.0             30.000000   30.0  30.000000
# mean   78.666667  82.500000  80.0             79.666667   80.0  79.166667
# std     4.901325   6.532413   0.0              6.686751    0.0   7.777436
# ...

# %%
df.describe().mean()
# Out:
# No                      16.475426
# Bahasa Indonesia        64.328166
# Bahasa Inggris          63.824245
# Matematika              64.635373
# Fisika                  63.806839
# Kimia                   63.570999
# Biologi                 66.597802
# PJOK                    63.750000
# Matematika_Peminatan    64.544177
# Agama                   63.750000
# Pkn                     63.680513
# Sejarah                 63.750000
# Seni                    64.798543
# Komputer                65.853807
# dtype: float64

# %%
df.describe().mean().max()
# Out:
# np.float64(66.59780156941693)

# %%
df.describe().mean().min()
# Out:
# np.float64(16.47542605385369)

# %%
df
# Out:
#     No               Nama  Bahasa Indonesia  Bahasa Inggris  Matematika  \
# 0    1               Aang                90              80          90
# 1    2               Ajis                80              70          90
# 2    3               Asri                70              70          90
# 3    4               Bayu                80              80          80
# 4    5              Bagas                90              90          70
# 5    6              Chery                80              90          75
# 6    7               Caca                75              80          80
# 7    8              Dimas                86              75          80
# 8    9              Elisa                70              75          85
# 9   10              Fadly                80              75          90
# 10  11              Ikbal                70              80          70
# 11  12  Muhammad Al madid                90              85          70
# ...

# %%
df['Jumlah NIlai'] = df['Bahasa Indonesia'] + df['Bahasa Inggris'] + df['Matematika'] + df['Fisika'] + df['Kimia'] + df['Biologi'] + df['PJOK'] + df['Matematika_Peminatan'] + df['Agama'] + df['Pkn '] + df['Sejarah'] + df['Seni'] + df['Komputer']

# %%
df['rata-rata'] = df['Bahasa Indonesia'] + df['Bahasa Inggris'] + df['Matematika'] + df['Fisika'] + df['Kimia'] + df['Biologi'] + df['PJOK'] + df['Matematika_Peminatan'] + df['Agama'] + df['Pkn '] + df['Sejarah'] + df['Seni'] + df['Komputer'] / len(df['Jumlah NIlai'])
df
# Out:
#     No               Nama  Bahasa Indonesia  Bahasa Inggris  Matematika  \
# 0    1               Aang                90              80          90
# 1    2               Ajis                80              70          90
# 2    3               Asri                70              70          90
# 3    4               Bayu                80              80          80
# 4    5              Bagas                90              90          70
# 5    6              Chery                80              90          75
# 6    7               Caca                75              80          80
# 7    8              Dimas                86              75          80
# 8    9              Elisa                70              75          85
# 9   10              Fadly                80              75          90
# 10  11              Ikbal                70              80          70
# 11  12  Muhammad Al madid                90              85          70
# ...

# %%
tertinggi = df[['Nama', 'Jumlah NIlai']].max()
tertinggi
# Out:
# Nama            Zeri
# Jumlah NIlai     1075
# dtype: object

# %%
tertinggi = df[['Nama', 'Jumlah NIlai']].min()
tertinggi
# Out:
# Nama            Aang
# Jumlah NIlai    1000
# dtype: object

# %%
jumlah = df['Jumlah NIlai'].mean()
jumlah
# Out:
# np.float64(1040.7333333333333)

# %%
tertinggi = df[['Nama', 'Matematika', 'Biologi', "Fisika", 'Kimia', 'Matematika_Peminatan']].max()
tertinggi
# Out:
# Nama                    Zeri
# Matematika                 90
# Biologi                    90
# Fisika                     90
# Kimia                      90
# Matematika_Peminatan       90
# dtype: object

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
import matplotlib.pyplot as plt

plt.style.use('bmh')

plt.barh(df['Nama'], df['Jumlah NIlai'])
plt.xlabel("NIlai Siswa")
plt.ylabel("Nama Siswa")
plt.title("Data siswa dengan Nilai siswa")
plt.show()
